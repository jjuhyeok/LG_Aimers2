# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_03_df = train.loc[:,'Y_Quality']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_A.loc[:,'Y_Quality']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_T.loc[:,'Y_Quality']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_O.loc[:,'Y_Quality']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_L1.loc[:,'Y_Quality']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_L2.loc[:,'Y_Quality']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_L3.loc[:,'Y_Quality']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_L4.loc[:,'Y_Quality']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_L5.loc[:,'Y_Quality']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_L6.loc[:,'Y_Quality']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_A.loc[:,'X_1111']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_A.loc[:,'X_1112']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_A.loc[:,'X_1113']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_A.loc[:,'Y_Class']
X_03_df.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_03')
plt.legend(fontsize=28, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_A.loc[:,'X_1115']
X_03_median_30 = train_A.loc[:,'Y_Class']
X_03_df.describe()
X_03_median_30.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='X_1115', color = 'b')
plt.plot(X_03_median_30, label='Y_Class', color = 'r')
plt.legend(fontsize=25, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()

# %%
X_03_df = train_A.loc[:,'Y_Quality']
X_03_median_30 = train_A.loc[:,'Y_Class']
X_03_df.describe()
X_03_median_30.describe()
plt.figure(figsize=(30,10))
plt.plot(X_03_df, label='Y_Quality', color = 'b')
plt.plot(X_03_median_30, label='Y_Class', color = 'r')
plt.legend(fontsize=25, loc = 'upper right')
plt.xticks(fontsize=28)
plt.yticks(fontsize=28) 
plt.show()
